# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# File paths
file_paths = [
    'claude_French_0_results.csv',
    'gpt4o_French_0_results.csv',
    'mistral_French_0_results.csv',
]

# Load and combine all datasets
all_data = []
for file_path in file_paths:
    data = pd.read_csv(file_path)
    dataset_name = '_'.join(file_path.split('_')[:2])  # Extract dataset name
    data['Dataset'] = dataset_name
    all_data.append(data[['Regular_JTC_Score', 'LEAP_JTC_Score', 'Dataset']])

# Combine all data
combined_data = pd.concat(all_data, ignore_index=True)

# Melt data for plotting
melted_data = combined_data.melt(
    id_vars=['Dataset'],
    value_vars=['Regular_JTC_Score', 'LEAP_JTC_Score'],
    var_name='Category',
    value_name='JTC Score'
)

# Order categories so Regular is always first
melted_data['Category'] = pd.Categorical(melted_data['Category'], categories=['Regular_JTC_Score', 'LEAP_JTC_Score'], ordered=True)

# Rename categories
category_mapping = {
    'Regular_JTC_Score': 'Regular',
    'LEAP_JTC_Score': 'LEAP'
}
melted_data['Category'] = melted_data['Category'].replace(category_mapping)

# Define custom colors
custom_palette = ['#87CEFA', 'steelblue']  # Lighter blue (#87CEFA) and orange

# Create the boxplot
plt.figure(figsize=(9, 6))  # Adjust width and height
sns.set(style="whitegrid")

# Use seaborn to create a box plot with skinnier boxes
sns.boxplot(
    data=melted_data,
    x='Dataset',
    y='JTC Score',
    hue='Category',
    palette=custom_palette,
    width=0.4  # Adjust box width to make it skinnier
)

# Add title and labels
plt.title('JTC Scores (Law - French)', fontsize=20)
plt.ylabel('JTC Score', fontsize=20)
plt.xlabel('Model', fontsize=20)
plt.ylim(0, 2)
plt.yticks(fontsize=16)

# Adjust the x-axis tick labels
plt.xticks(
    ticks=range(len(file_paths)),
    labels=['Claude', 'GPT', 'Mistral'],  # Custom model names
    fontsize=16
)

# Add legend
plt.legend(loc='upper right', fontsize=18)

# Show the plot
plt.tight_layout()
plt.savefig('french_0_results.png', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# <ipython-input-18-3452631b0125>:39: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   melted_data['Category'] = melted_data['Category'].replace(category_mapping)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# File paths
file_paths = [
    'claude_French_1_results.csv',
    'gpt4o_French_1_results.csv',
    'mistral_French_1_results.csv',
]

# Load and combine all datasets
all_data = []
for file_path in file_paths:
    data = pd.read_csv(file_path)
    dataset_name = '_'.join(file_path.split('_')[:2])  # Extract dataset name
    data['Dataset'] = dataset_name
    all_data.append(data[['Regular_JTC_Score', 'LEAP_JTC_Score', 'Dataset']])

# Combine all data
combined_data = pd.concat(all_data, ignore_index=True)

# Melt data for plotting
melted_data = combined_data.melt(
    id_vars=['Dataset'],
    value_vars=['Regular_JTC_Score', 'LEAP_JTC_Score'],
    var_name='Category',
    value_name='JTC Score'
)

# Order categories so Regular is always first
melted_data['Category'] = pd.Categorical(melted_data['Category'], categories=['Regular_JTC_Score', 'LEAP_JTC_Score'], ordered=True)

# Rename categories
category_mapping = {
    'Regular_JTC_Score': 'Regular',
    'LEAP_JTC_Score': 'LEAP'
}
melted_data['Category'] = melted_data['Category'].replace(category_mapping)

# Define custom colors
custom_palette = ['#87CEFA', 'steelblue']  # Lighter blue (#87CEFA) and orange

# Create the boxplot
plt.figure(figsize=(9, 6))  # Adjust width and height
sns.set(style="whitegrid")

# Use seaborn to create a box plot with skinnier boxes
sns.boxplot(
    data=melted_data,
    x='Dataset',
    y='JTC Score',
    hue='Category',
    palette=custom_palette,
    width=0.4  # Adjust box width to make it skinnier
)

# Add title and labels
plt.title('JTC Scores (Medical - French)', fontsize=20)
plt.ylabel('JTC Score', fontsize=20)
plt.xlabel('Model', fontsize=20)
plt.ylim(0, 2)
plt.yticks(fontsize=16)

# Adjust the x-axis tick labels
plt.xticks(
    ticks=range(len(file_paths)),
    labels=['Claude', 'GPT', 'Mistral'],  # Custom model names
    fontsize=16
)

# Add legend
plt.legend(loc='upper right', fontsize=18)

# Show the plot
plt.tight_layout()
plt.savefig('french_1_results.png', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# <ipython-input-19-214d0e07e0b6>:39: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   melted_data['Category'] = melted_data['Category'].replace(category_mapping)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# File paths
file_paths = [
    'claude_Simplified_Chinese_0_results.csv',
    'gpt4o_Simplified_Chinese_0_results.csv',
    'mistral_Simplified_Chinese_0_results.csv',
]

# Load and combine all datasets
all_data = []
for file_path in file_paths:
    data = pd.read_csv(file_path)
    dataset_name = '_'.join(file_path.split('_')[:2])  # Extract dataset name
    data['Dataset'] = dataset_name
    all_data.append(data[['Regular_JTC_Score', 'LEAP_JTC_Score', 'Dataset']])

# Combine all data
combined_data = pd.concat(all_data, ignore_index=True)

# Melt data for plotting
melted_data = combined_data.melt(
    id_vars=['Dataset'],
    value_vars=['Regular_JTC_Score', 'LEAP_JTC_Score'],
    var_name='Category',
    value_name='JTC Score'
)

# Order categories so Regular is always first
melted_data['Category'] = pd.Categorical(melted_data['Category'], categories=['Regular_JTC_Score', 'LEAP_JTC_Score'], ordered=True)

# Rename categories
category_mapping = {
    'Regular_JTC_Score': 'Regular',
    'LEAP_JTC_Score': 'LEAP'
}
melted_data['Category'] = melted_data['Category'].replace(category_mapping)

# Define custom colors
custom_palette = ['#87CEFA', 'steelblue']  # Lighter blue (#87CEFA) and orange

# Create the boxplot
plt.figure(figsize=(9, 6))  # Adjust width and height
sns.set(style="whitegrid")

# Use seaborn to create a box plot with skinnier boxes
sns.boxplot(
    data=melted_data,
    x='Dataset',
    y='JTC Score',
    hue='Category',
    palette=custom_palette,
    width=0.4  # Adjust box width to make it skinnier
)

# Add title and labels
plt.title('JTC Scores (Law - Chinese)', fontsize=20)
plt.ylabel('JTC Score', fontsize=20)
plt.xlabel('Model', fontsize=20)
plt.ylim(0, 2)
plt.yticks(fontsize=16)

# Adjust the x-axis tick labels
plt.xticks(
    ticks=range(len(file_paths)),
    labels=['Claude', 'GPT', 'Mistral'],  # Custom model names
    fontsize=16
)

# Add legend
plt.legend(loc='upper right', fontsize=18)

# Show the plot
plt.tight_layout()
plt.savefig('chinese_0_results.png', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# <ipython-input-20-cf3e6f122524>:39: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   melted_data['Category'] = melted_data['Category'].replace(category_mapping)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# File paths
file_paths = [
    'claude_Simplified_Chinese_1_results.csv',
    'gpt4o_Simplified_Chinese_1_results.csv',
    'mistral_Simplified_Chinese_1_results.csv',
]

# Load and combine all datasets
all_data = []
for file_path in file_paths:
    data = pd.read_csv(file_path)
    dataset_name = '_'.join(file_path.split('_')[:2])  # Extract dataset name
    data['Dataset'] = dataset_name
    all_data.append(data[['Regular_JTC_Score', 'LEAP_JTC_Score', 'Dataset']])

# Combine all data
combined_data = pd.concat(all_data, ignore_index=True)

# Melt data for plotting
melted_data = combined_data.melt(
    id_vars=['Dataset'],
    value_vars=['Regular_JTC_Score', 'LEAP_JTC_Score'],
    var_name='Category',
    value_name='JTC Score'
)

# Order categories so Regular is always first
melted_data['Category'] = pd.Categorical(melted_data['Category'], categories=['Regular_JTC_Score', 'LEAP_JTC_Score'], ordered=True)

# Rename categories
category_mapping = {
    'Regular_JTC_Score': 'Regular',
    'LEAP_JTC_Score': 'LEAP'
}
melted_data['Category'] = melted_data['Category'].replace(category_mapping)

# Define custom colors
custom_palette = ['#87CEFA', 'steelblue']  # Lighter blue (#87CEFA) and orange

# Create the boxplot
plt.figure(figsize=(9, 6))  # Adjust width and height
sns.set(style="whitegrid")

# Use seaborn to create a box plot with skinnier boxes
sns.boxplot(
    data=melted_data,
    x='Dataset',
    y='JTC Score',
    hue='Category',
    palette=custom_palette,
    width=0.4  # Adjust box width to make it skinnier
)

# Add title and labels
plt.title('JTC Scores (Medical - Chinese)', fontsize=20)
plt.ylabel('JTC Score', fontsize=20)
plt.xlabel('Model', fontsize=20)
plt.ylim(0, 2)
plt.yticks(fontsize=16)

# Adjust the x-axis tick labels
plt.xticks(
    ticks=range(len(file_paths)),
    labels=['Claude', 'GPT', 'Mistral'],  # Custom model names
    fontsize=16
)

# Add legend
plt.legend(loc='upper right', fontsize=18)

# Show the plot
plt.tight_layout()
plt.savefig('chinese_1_results.png', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# <ipython-input-21-01cbeaa74e71>:39: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   melted_data['Category'] = melted_data['Category'].replace(category_mapping)
